# %%
# %load_ext autoreload
# %autoreload 2
import warnings
warnings.filterwarnings('ignore')
from pipeline import loader as lo
from pipeline import classifier as clas
from pipeline import explorer as ex
from pipeline import preprocessor as pro
from pipeline import _util as ut
from pipeline import evaluator as ev
from pipeline import features_generator as fe
from datetime import timedelta
import pandas as pd
# Out:
# /usr/local/lib/python3.5/dist-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /usr/local/lib/python3.5/dist-packages/sklearn/ensemble/weight_boosting.py:29: DeprecationWarning: numpy.core.umath_tests is an internal NumPy module and should not be imported. It will be removed in a future NumPy release.
#   from numpy.core.umath_tests import inner1d
# /usr/local/lib/python3.5/dist-packages/sklearn/grid_search.py:42: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. This module will be removed in 0.20.
#   DeprecationWarning)

# %% [markdown]
# # Models evaluation ( pipeline skeleton)

# %% [markdown]
# ## 1. Load Data
# #### - Load data from csv file
# #### - Check the data type of each column

# %%
df = lo.load('projects_2012_2013.csv')

# %%
df.dtypes
# Out:
# projectid                                  object
# teacher_acctid                             object
# schoolid                                   object
# school_ncesid                             float64
# school_latitude                           float64
# school_longitude                          float64
# school_city                                object
# school_state                               object
# school_metro                               object
# school_district                            object
# school_county                              object
# school_charter                             object
# school_magnet                              object
# teacher_prefix                             object
# primary_focus_subject                      object
# primary_focus_area                         object
# secondary_focus_subject                    object
# secondary_focus_area                       object
# resource_type                              object
# poverty_level                              object
# grade_level                                object
# total_price_including_optional_support    float64
# students_reached                          float64
# eligible_double_your_impact_match          object
# date_posted                                object
# datefullyfunded                            object
# dtype: object

# %% [markdown]
# ## 2. Explore Data

# %% [markdown]
# ### show the missing rate of each column

# %%
df.isnull().sum(axis=0)/ df.shape[0]
# Out:
# projectid                                 0.000000
# teacher_acctid                            0.000000
# schoolid                                  0.000000
# school_ncesid                             0.073878
# school_latitude                           0.000000
# school_longitude                          0.000000
# school_city                               0.000000
# school_state                              0.000000
# school_metro                              0.121815
# school_district                           0.001376
# school_county                             0.000000
# school_charter                            0.000000
# school_magnet                             0.000000
# teacher_prefix                            0.000000
# primary_focus_subject                     0.000120
# primary_focus_area                        0.000120
# secondary_focus_subject                   0.324510
# secondary_focus_area                      0.324510
# resource_type                             0.000136
# poverty_level                             0.000000
# grade_level                               0.000024
# total_price_including_optional_support    0.000000
# students_reached                          0.000472
# eligible_double_your_impact_match         0.000000
# date_posted                               0.000000
# datefullyfunded                           0.000000
# dtype: float64

# %% [markdown]
# ## 3 label the data's outcome

# %%
df['date_posted'] = pd.to_datetime(df['date_posted'])
df['datefullyfunded'] = pd.to_datetime(df['datefullyfunded'])
df['not_funded_in_60_days'] = \
    (df['datefullyfunded'] - df['date_posted'] >= pd.to_timedelta(60, unit='days')).astype('int')

# %% [markdown]
# Notice we care about the project that is not fully funded in 60 days, so we label the outcome of not get funded in 60 days as 1 else as 0.

# %% [markdown]
# ## 4 Run the main function

# %%
xs_lst = [item for item in df.columns if item not in {'date_posted',
                                                      'datefullyfunded',
                                                      'not_funded_in_60_days',
                                                      'projectid',
                                                      'teacher_acctid',
                                                      'schoolid',
                                                      'school_ncesid'}]
grid_size = 'test'
clfs, grid = clas.define_clfs_params(grid_size)
models_to_run=['DT','LR','RF','AB', 'GB','ET','BG']
res = main.run_time_validation(models_to_run, clfs, grid, grid_size,
    df, '2012-01-01' ,'2014-1-1' , 6, 6, 'date_posted', xs_lst, ['not_funded_in_60_days'])
# Out:
# 2012-01-01 00:00:00 2013-05-02 00:00:00 2013-07-01 00:00:00 2014-01-01 00:00:00
# ---------------------------------------------------------------------------
# MemoryError                               Traceback (most recent call last)
# <ipython-input-13-eee4abc78b0a> in <module>()
#      10 models_to_run=['DT','LR','RF','AB', 'GB','ET','BG']
#      11 res = main.run_time_validation(models_to_run, clfs, grid, grid_size,
# ---> 12     df, '2012-01-01' ,'2014-1-1' , 6, 6, 'date_posted', xs_lst, ['not_funded_in_60_days'])
#
# ~/ml_hws/machine_learning_hws/hw5/main.py in run_time_validation(models_to_run, clfs, grid, grid_size, df, start_time, end_time, prediction_window, update_window, time_col, x_cols, y_col)
#     167         x_test = x_test[cols]
#     168         temp = clf_loop(models_to_run, clfs, grid, x_train, x_test, y_train, y_test, grid_size,
# --> 169             train_start, train_end, test_start, test_end )
#     170         res_lst.append(temp)
#     171     res = pd.concat(res_lst)
#
# ~/ml_hws/machine_learning_hws/hw5/main.py in clf_loop(models_to_run, clfs, grid, X_train, X_test, y_train, y_test, grid_size, train_start, train_end, test_start, test_end)
#     101                   ))
#     102
# --> 103     baseline_clf = ev.baseline(X_train, X_test, y_train, y_test)
#     104     baseline_y_pred_probs= baseline_clf.predict_proba(X_test)[:,1]
#     105     baseline_y_pred_probs_sorted, base_y_test_sorted = zip(*sorted(zip(baseline_y_pred_probs, y_test), reverse=True))
#
# ~/ml_hws/machine_learning_hws/hw5/pipeline/evaluator.py in baseline(X_train, X_test, y_train, y_test)
#      89 def baseline(X_train, X_test, y_train, y_test):
#      90     clf = DummyClassifier(strategy='stratified', random_state=0)
# ---> 91     clf.fit(X_train, y_train)
#      92     return clf
#      93
#
# /usr/local/lib/python3.5/dist-packages/sklearn/dummy.py in fit(self, X, y, sample_weight)
#     108         """
#     109         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'],
# --> 110                         force_all_finite=False)
#     111
#     112         if self.strategy not in ("most_frequent", "stratified", "uniform",
#
# /usr/local/lib/python3.5/dist-packages/sklearn/utils/validation.py in check_array(array, accept_sparse, dtype, order, copy, force_all_finite, ensure_2d, allow_nd, ensure_min_samples, ensure_min_features, warn_on_dtype, estimator)
#     431                                       force_all_finite)
#     432     else:
# --> 433         array = np.array(array, dtype=dtype, order=order, copy=copy)
#     434
#     435         if ensure_2d:
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in __array__(self, dtype)
#    1604
#    1605     def __array__(self, dtype=None):
# -> 1606         return com._values_from_object(self)
#    1607
#    1608     def __array_wrap__(self, result, context=None):
#
# pandas/_libs/lib.pyx in pandas._libs.lib.values_from_object()
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in get_values(self)
#    4686                [nan,  3.]])
#    4687         """
# -> 4688         return self.values
#    4689
#    4690     def get_dtype_counts(self):
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/generic.py in values(self)
#    4631         """
#    4632         self._consolidate_inplace()
# -> 4633         return self._data.as_array(transpose=self._AXIS_REVERSED)
#    4634
#    4635     @property
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in as_array(self, transpose, items)
#    3947             arr = mgr.blocks[0].get_values()
#    3948         else:
# -> 3949             arr = mgr._interleave()
#    3950
#    3951         return arr.transpose() if transpose else arr
#
# /usr/local/lib/python3.5/dist-packages/pandas/core/internals.py in _interleave(self)
#    3958         dtype = _interleaved_dtype(self.blocks)
#    3959
# -> 3960         result = np.empty(self.shape, dtype=dtype)
#    3961
#    3962         if result.shape[0] == 0:
#
# MemoryError:

# %% [markdown]
# ## 4 Build all the models

# %%
grid_size = 'test'
clfs, grid = clas.define_clfs_params(grid_size)
models_to_run=['RF','DT','KNN', 'ET', 'AB', 'GB', 'LR', 'NB','BG']
res = main.run_time_validation(models_to_run, clfs, grid, grid_size,
    df, '2012-01-01' ,'2014-1-1' , 6, 6, 'date_posted', xs_lst, ['fully_funded_in_60_days'])
# Out:
# 2012-01-01 00:00:00 2013-05-02 00:00:00 2013-07-01 00:00:00 2014-01-01 00:00:00
# RF
# DT
# KNN
# ET
# AB
# GB
# LR
# NB
# BG
# 2012-01-01 00:00:00 2012-11-02 00:00:00 2013-01-01 00:00:00 2013-07-01 00:00:00
# RF
# DT
# KNN
# ET
# AB
# GB
# LR
# NB
# BG
# 2012-01-01 00:00:00 2012-05-02 00:00:00 2012-07-01 00:00:00 2013-01-01 00:00:00
# RF
# DT
# KNN
# ET
# AB
# GB
# LR
# NB
# BG

# %%
res.columns
# Out:
# Index(['train_start', 'train_end', 'test_start', 'test_end', 'model_type',
#        'clf', 'parameters', 'auc-roc', 'baseline_at_1', 'baseline_at_2',
#        'baseline_at_5', 'baseline_at_10', 'baseline_at_20', 'baseline_at_30',
#        'baseline_at_50', 'accuracy_at_1', 'accuracy_at_2', 'accuracy_at_5',
#        'accuracy_at_10', 'accuracy_at_20', 'accuracy_at_30', 'accuracy_at_50',
#        'precision_at_1', 'precision_at_2', 'precision_at_5', 'precision_at_10',
#        'precision_at_20', 'precision_at_30', 'precision_at_50', 'recall_at_1',
#        'recall_at_2', 'recall_at_5', 'recall_at_10', 'recall_at_20',
#        'recall_at_30', 'recall_at_50'],
#       dtype='object')

# %% [markdown]
# ## 5. Compare all the models

# %%
lst = ['auc-roc','accuracy_at_1', 'accuracy_at_2', 'accuracy_at_5',
       'accuracy_at_10', 'accuracy_at_20', 'accuracy_at_30', 'accuracy_at_50',
       'precision_at_1', 'precision_at_2', 'precision_at_5', 'precision_at_10',
       'precision_at_20', 'precision_at_30', 'precision_at_50', 'recall_at_1',
       'recall_at_2', 'recall_at_5', 'recall_at_10', 'recall_at_20',
       'recall_at_30', 'recall_at_50']
res_lst =[]
for item in lst:
    temp = res.sort_values(by = item,ascending = False).head(1)[['model_type','parameters','clf','train_start','train_end',item]]
    temp['metrics']  = item
    temp.rename(columns = {item:'score'},inplace =True)
    temp_1 = temp[['model_type','metrics', 'train_end','score']]
    res_lst.append(temp_1)
best_models = pd.concat(res_lst)
# Out:
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                   0.692914
# metrics                                                  auc-roc
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                   0.743598
# metrics                                            accuracy_at_1
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                   0.742021
# metrics                                            accuracy_at_2
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                     0.7375
# metrics                                            accuracy_at_5
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                     0.7304
# metrics                                           accuracy_at_10
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                   0.706189
# metrics                                           accuracy_at_20
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                   0.681572
# metrics                                           accuracy_at_30
# Name: 0, dtype: object
# model_type                                                   KNN
# parameters     {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...
# clf            KNeighborsClassifier(algorithm='auto', leaf_si...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.618372
# metrics                                           accuracy_at_50
# Name: 2, dtype: object
# model_type                                                    GB
# parameters     {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# clf            ([DecisionTreeRegressor(criterion='friedman_ms...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.631336
# metrics                                           precision_at_1
# Name: 5, dtype: object
# model_type                                                    GB
# parameters     {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# clf            ([DecisionTreeRegressor(criterion='friedman_ms...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.608295
# metrics                                           precision_at_2
# Name: 5, dtype: object
# model_type                                                    AB
# parameters           {'algorithm': 'SAMME', 'n_estimators': 100}
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.560369
# metrics                                           precision_at_5
# Name: 4, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.537327
# metrics                                          precision_at_10
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.506105
# metrics                                          precision_at_20
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.483415
# metrics                                          precision_at_30
# Name: 0, dtype: object
# model_type                                                   KNN
# parameters     {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...
# clf            KNeighborsClassifier(algorithm='auto', leaf_si...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-11-02 00:00:00
# score                                                   0.434258
# metrics                                          precision_at_50
# Name: 2, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                  0.0204299
# metrics                                              recall_at_1
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                  0.0388164
# metrics                                              recall_at_2
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                  0.0942571
# metrics                                              recall_at_5
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                   0.177458
# metrics                                             recall_at_10
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                   0.327315
# metrics                                             recall_at_20
# Name: 0, dtype: object
# model_type                                                    RF
# parameters     {'max_features': 'sqrt', 'min_samples_split': ...
# clf            (DecisionTreeClassifier(class_weight=None, cri...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2013-05-02 00:00:00
# score                                                   0.467626
# metrics                                             recall_at_30
# Name: 0, dtype: object
# model_type                                                   KNN
# parameters     {'algorithm': 'auto', 'n_neighbors': 3, 'weigh...
# clf            KNeighborsClassifier(algorithm='auto', leaf_si...
# train_start                                  2012-01-01 00:00:00
# train_end                                    2012-05-02 00:00:00
# score                                                   0.715045
# metrics                                             recall_at_50
# Name: 2, dtype: object

# %%
best_models
# Out:
#   model_type          metrics  train_end     score
# 0         RF          auc-roc 2013-05-02  0.692914
# 0         RF    accuracy_at_1 2012-05-02  0.743598
# 0         RF    accuracy_at_2 2012-05-02  0.742021
# 0         RF    accuracy_at_5 2012-05-02  0.737500
# 0         RF   accuracy_at_10 2012-05-02  0.730400
# 0         RF   accuracy_at_20 2012-05-02  0.706189
# 0         RF   accuracy_at_30 2013-05-02  0.681572
# 2        KNN   accuracy_at_50 2012-11-02  0.618372
# 5         GB   precision_at_1 2012-11-02  0.631336
# 5         GB   precision_at_2 2012-11-02  0.608295
# 4         AB   precision_at_5 2012-11-02  0.560369
# 0         RF  precision_at_10 2012-11-02  0.537327
# 0         RF  precision_at_20 2012-11-02  0.506105
# 0         RF  precision_at_30 2012-11-02  0.483415
# 2        KNN  precision_at_50 2012-11-02  0.434258
# 0         RF      recall_at_1 2012-05-02  0.020430
# 0         RF      recall_at_2 2013-05-02  0.038816
# 0         RF      recall_at_5 2013-05-02  0.094257
# 0         RF     recall_at_10 2013-05-02  0.177458
# 0         RF     recall_at_20 2013-05-02  0.327315
# 0         RF     recall_at_30 2013-05-02  0.467626
# 2        KNN     recall_at_50 2012-05-02  0.715045

# %%
res.sort_values(by = 'precision_at_5',ascending = False).head(10)[['model_type','parameters','clf','train_start','train_end','precision_at_5']]
# Out:
#   model_type                                         parameters  \
# 4         AB        {'algorithm': 'SAMME', 'n_estimators': 100}
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 6         LR                       {'C': 0.01, 'penalty': 'l1'}
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 4         AB        {'algorithm': 'SAMME', 'n_estimators': 100}
# 6         LR                       {'C': 0.01, 'penalty': 'l1'}
#
#                                                  clf train_start  train_end  \
# 4  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2012-11-02
# 6  LogisticRegression(C=0.01, class_weight=None, ...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2013-05-02
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2013-05-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2012-11-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2013-05-02
# 4  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2013-05-02
# 6  LogisticRegression(C=0.01, class_weight=None, ...  2012-01-01 2013-05-02
#
#    precision_at_5
# 4        0.560369
# 0        0.550230
# 5        0.548387
# 6        0.539171
# 0        0.533062
# 5        0.520380
# 3        0.481106
# 3        0.479620
# 4        0.474185
# 6        0.471920

# %%
res.sort_values(by = 'precision_at_1',ascending = False).head(10)[['model_type','parameters','clf','train_start','train_end','precision_at_1']]
# Out:
#   model_type                                         parameters  \
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 4         AB        {'algorithm': 'SAMME', 'n_estimators': 100}
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 6         LR                       {'C': 0.01, 'penalty': 'l1'}
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
#
#                                                  clf train_start  train_end  \
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2012-11-02
# 4  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2013-05-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2012-11-02
# 6  LogisticRegression(C=0.01, class_weight=None, ...  2012-01-01 2012-11-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2013-05-02
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2013-05-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-05-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2012-05-02
#
#    precision_at_1
# 0        0.617512
# 5        0.617512
# 4        0.599078
# 0        0.589569
# 3        0.557604
# 6        0.543779
# 3        0.532880
# 5        0.521542
# 0        0.486322
# 3        0.480243

# %%
res.sort_values(by = 'precision_at_2',ascending = False).head(10)[['model_type','parameters','clf','train_start','train_end','precision_at_2']]
# Out:
#   model_type                                         parameters  \
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 6         LR                       {'C': 0.01, 'penalty': 'l1'}
# 4         AB        {'algorithm': 'SAMME', 'n_estimators': 100}
# 5         GB  {'learning_rate': 0.1, 'subsample': 0.5, 'max_...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 3         ET  {'max_features': 'sqrt', 'min_samples_split': ...
# 0         RF  {'max_features': 'sqrt', 'min_samples_split': ...
# 6         LR                       {'C': 0.01, 'penalty': 'l1'}
#
#                                                  clf train_start  train_end  \
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2013-05-02
# 6  LogisticRegression(C=0.01, class_weight=None, ...  2012-01-01 2012-11-02
# 4  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-11-02
# 5  ([DecisionTreeRegressor(criterion='friedman_ms...  2012-01-01 2013-05-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2013-05-02
# 3  (ExtraTreeClassifier(class_weight=None, criter...  2012-01-01 2012-11-02
# 0  (DecisionTreeClassifier(class_weight=None, cri...  2012-01-01 2012-05-02
# 6  LogisticRegression(C=0.01, class_weight=None, ...  2012-01-01 2013-05-02
#
#    precision_at_2
# 5        0.615207
# 0        0.573733
# 0        0.571914
# 6        0.557604
# 4        0.550691
# 5        0.539071
# 3        0.516421
# 3        0.511521
# 0        0.473445
# 6        0.458664

# %%
from IPython.display import HTML

HTML('''<script>
code_show=true; 
function code_toggle() {
 if (code_show){
 $('div.input').hide();
 } else {
 $('div.input').show();
 }
 code_show = !code_show
} 
$( document ).ready(code_toggle);
</script>
<form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>''')
# Out:
# <script>
# code_show=true;
# function code_toggle() {
#  if (code_show){
#  $('div.input').hide();
#  } else {
#  $('div.input').show();
#  }
#  code_show = !code_show
# }
# $( document ).ready(code_toggle);
# </script>
# <form action="javascript:code_toggle()"><input type="submit" value="Click here to toggle on/off the raw code."></form>
